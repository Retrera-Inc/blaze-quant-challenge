# %% [markdown]
# # Meet the Lightning AI Studio
#
# Code from the cloud or connect your local IDE. You can **run one Studio for free** at anytime.
# No setup - Installed dependencies, files and data are available when you restart the Studio or add GPUs!
#
# ## Next Steps:
# 1. Get your code on the Studio or try our examples.

# %%
# Clone a repo or drag and drop files into the screen
! git clone https://github.com/octocat/Hello-World.git

# %% [markdown]
# 2. Add your data (use the Drive plugin on the right side).
# ![image.png](attachment:image.png)
# 3. Experts - Connect your laptop IDE by hovering on the VSCode or ssh plugin.
# ![image-2.png](attachment:image-2.png)
# 4. Install the laptop app (find this button in the browser search bar).
#
#     ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #

# %% [markdown]
# ---
# ## 7 Key principles
# - Principle 1: A Studio is a SINGLE environment.
# - Principle 2: Switch GPUs in the same environment.
# - Principle 3: Treat a Studio like your laptop.
# - Principle 4: Get 1 free running Studio and 15 free credits monthly.
# - Principle 5: Studios share the same file system.
# - Principle 6: Plugins, plugins, plugins!
# - Principle 7: Click the help button for help!
# - FAQ

# %%
! pip install cowsay --quiet
import cowsay
cowsay.cow(f'git clone your code, bring data and start!')
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
#   __________________________________________
# | git clone your code, bring data and start! |
# ...
#                                           \
#                                            \
#                                              ^__^
#                                              (oo)\_______
#                                              (__)\       )\/\
#                                                  ||----w |
#                                                  ||     ||

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ---
#
# ## Principle 1 - A Studio is a SINGLE environment
# #
#
# This Studio has a single environment (conda).
#
# - To create a different environment, start a new Studio.
# - When a Studio wakes up, files, data and dependencies will still be there!
# - Setup a Studio (environment) per project you are work on. That way, when you want to work on that, simply start the Studio and all your files and dependencies will be ready.
#
# Yes, it's different than your laptop, but this is better. Every Studio is like having a disposable laptop on the cloud. If you mess up the environment, simply start a new Studio!

# %%
! conda env list

# %%
cowsay.cow(f"got it, when I need a new environment, i'll start a new Studio")
# Out:
#   _________________________________________________
#  /                                                 \
# | got it, when I need a new environment, i'll start |
# |  a new Studio                                     |
#  \                                                 /
# ...
#                                                  \
#                                                   \
#                                                     ^__^
#                                                     (oo)\_______
#                                                     (__)\       )\/\
#                                                         ||----w |
#                                                         ||     ||

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ---
# ## Principle 2: Switch GPUs in the same environment.
#
# Click this button (top right) to attach GPUs.
# ![image.png](attachment:image.png)
#
# The environment, dependencies, files and data stay the same!

# %%
cowsay.cow('I can run on 1 or 4 GPUs in the same environment? 🤯 🤯 🤯')
# Out:
#   _________________________________________________
#  /                                                 \
# | I can run on 1 or 4 GPUs in the same environment? |
# |  🤯 🤯 🤯                                            |
#  \                                                 /
# ...
#                                                  \
#                                                   \
#                                                     ^__^
#                                                     (oo)\_______
#                                                     (__)\       )\/\
#                                                         ||----w |
#                                                         ||     ||

# %% [markdown]
# #
# #

# %% [markdown]
# #

# %% [markdown]
# ---
# ## Principle 3: Treat a Studio like your laptop
#
# There is nothing new to learn:
# - Want to install something? simply (pip install) or (conda install) or (apt-get install).
# - Want to change the python or cuda version? open a terminal and just do it!
# - Want to clone a repo? open a terminal and just do it...
# - Want to run docker? open a terminal and just do it...
#
# Get the idea? A Studio is exactly like your laptop, expect on the cloud, and you can attach GPUs to it

# %%
cowsay.cow("moo kay, if i'm stuck, i'll open a terminal and do what i would do on my laptop")
# Out:
#   _________________________________________________
#  /                                                 \
# | moo kay, if i'm stuck, i'll open a terminal and d |
# | o what i would do on my laptop                    |
#  \                                                 /
# ...
#                                                  \
#                                                   \
#                                                     ^__^
#                                                     (oo)\_______
#                                                     (__)\       )\/\
#                                                         ||----w |
#                                                         ||     ||

# %%
! git clone https://github.com/octocat/Hello-World.git --quiet
! docker ps
# Out:
# fatal: destination path 'Hello-World' already exists and is not an empty directory.
#
#
# To fix this issue:
# 1. Verify the repository name for accuracy and retry.
# 2. Grant access to the Lightning-GitHub integration for organization repositories at:
#    https://github.com/settings/connections/applications/c7457225b242a94d60c6
#
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ---
# ## Principle 4: Get 1 free running Studio and 15 free credits monthly
#
# We hooked you up! You get:
# - One CPU Studio running for free at any one time.
# - 30 monthly credits (1 credit = $1). Use those credits to run on GPUs or start other Studios at the same time.

# %%
cowsay.cow("wow, so i can code on the cloud for free?? and 30 credits is about 12 T4 GPU hours? ")
# Out:
#   _________________________________________________
#  /                                                 \
# | wow, so i can code on the cloud for free?? and 30 |
# |  credits is about 12 T4 GPU hours?                |
#  \                                                 /
# ...
#                                                  \
#                                                   \
#                                                     ^__^
#                                                     (oo)\_______
#                                                     (__)\       )\/\
#                                                         ||----w |
#                                                         ||     ||

# %% [markdown]
# #
# #

# %% [markdown]
# #

# %% [markdown]
# ---
# ## Principle 5: Studios share the same file system.
#
# All Studios share the same filesystem. This unblocks sooo many things for you!
#
# example 1: Train + server
#
# - Start a Studio to train a model.
# - Start a second Studio to serve the model or analyze it.
# - move the checkpoints using the CLI (or our Drive).

# %%
cowsay.cow("phew... i can process data on a Studio and train on another without transferring data anywhere...")
# Out:
#   _________________________________________________
#  /                                                 \
# | phew... i can process data on a Studio and train  |
# | on another without transferring data anywhere...  |
#  \                                                 /
# ...
#                                                  \
#                                                   \
#                                                     ^__^
#                                                     (oo)\_______
#                                                     (__)\       )\/\
#                                                         ||----w |
#                                                         ||     ||

# %%
# list datasets, and other studios
! ls /teamspace/
# Out:
# jobs  s3_connections  studios

# %%
# list other studios
! ls /teamspace/studios

# %%
# grab files from a separate Studio (make sure to start the second studio first)
# ! cp /teamspace/studios/studio_b/checkpoint ~/.

# %% [markdown]
# Now you will never need to deal with moving files around again!

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ---
# ## Principle 6: - Plugins, plugins, plugins!
#
# Need to train on multiple machines (multi-node)? there's a plugin for that!
#
# We have plugins for:
#
# - Tensorboard
# - Streamlit
# - Gradio
# - Train on multi-node
# - Serving
# - Distributed data processing
# - Shared file system
# - VSCode, Jupyter
# - and more!
#
# Explore plugins on the right side!

# %%
cowsay.cow(f"phew... i don't need 30 different platforms now, I can do it all within the same Studio!")
# Out:
#   _________________________________________________
#  /                                                 \
# | phew... i don't need 30 different platforms now,  |
# | I can do it all within the same Studio!           |
#  \                                                 /
# ...
#                                                  \
#                                                   \
#                                                     ^__^
#                                                     (oo)\_______
#                                                     (__)\       )\/\
#                                                         ||----w |
#                                                         ||     ||

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ## Principle 7: Click this button for help
#
# To learn more about something, find this button and click on it for a tutorial!
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Quick game: Pick a number between 1 and 5

# %%
import torch
guess = torch.randint(low=1, high=6, size=(1,)).item()
cowsay.cow(f"my guess is: {guess}")
# Out:
#   ______________
# | my guess is: 4 |
# ...
#               \
#                \
#                  ^__^
#                  (oo)\_______
#                  (__)\       )\/\
#                      ||----w |
#                      ||     ||

# %% [markdown]
# Happy coding!
#
# \- Will Falcon and the Lightning team ⚡️

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ---
# ## FAQ

# %% [markdown]
# ### Q: What is a persistent environment?
# Whenever you turn on/off the Studio or add GPUs, the environment does not change.
# Anything you installed (pip, conda, etc...), your data and files will be there next time the Studio is live again!

# %% [markdown]
# #

# %% [markdown]
# ### Q: How do I run on my own AWS account?
# Click on [teamspace settings](https://lightning.ai/), and click "add cloud account". It takes about 5 minutes to add. Once it's added, you can start Studios on that cloud account.

# %% [markdown]
# #

# %% [markdown]
# ### Q: How do I add an S3 bucket?
# Use the Drive plugin on the top right

# %% [markdown]
# #

# %% [markdown]
# ### Q: How is this different than my laptop?
# - This is on the cloud and your laptop is not. This means you can put data, code, checkpoints here and give collaborators access to these files.
# - When you close your laptop, the code stops running. Here, the code keeps running even if you close the browser.
# - Coding is free on Studio because you get a free running CPU Studio. To code something else, stop the Studio and start a new one for free!
# - The Studio environment is permanent... so you know that every time you want to work on something, it will be there. On your laptop you have to setup environments all the time.
# - A Studio can add up to 8 GPUs unlike your laptop. It also has unlimited storage.

# %% [markdown]
# #

# %% [markdown]
# ### Q: I don't like coding on a browser
# Hover over the VSCode plugin or the SSH plugin, and connect to the Studio from your laptop's IDE!

# %% [markdown]
# #

# %% [markdown]
# ### Q: This is crazy, how did you do this?
# A lot of hard work with an amazing team! We are hiring!
